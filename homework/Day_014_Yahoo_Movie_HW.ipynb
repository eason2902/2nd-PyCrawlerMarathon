# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'
soup = BeautifulSoup(resp.text, 'lxml')

# %%
#soup.main.find_all('select') 不夠乾淨
row = soup.find(id = "sbox_mid").find_all('option')[1]
for row in soup.find(id = "sbox_mid").find_all('option'): 
    try: #第一個row為<option value="">請選擇片名</option>
        print('movie:',row['data-name'],'ID:',row['value'])
    except:
        continue
#print(row)
#print('movie:',row['data-name'],'ID:',row['value']) #row這標籤列中屬性名為'data-name'的屬性值
# Out:
#   File "<ipython-input-62-4842ac5f0c2b>", line 6
#     except:
#          ^
# IndentationError: expected an indented block

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh_TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="501887343352051" property="fb:app_id"/>
# <meta content="Yahoo奇摩電影" property="og:site_name"/>
# <title>Yahoo奇摩電影</title>
# <meta content="Yahoo奇摩電影" name="twitter:title"/>
# <meta content="Yahoo奇摩電影" property="og:title"/>
# <link href="https://movies.yahoo.com.tw" rel="canonical"/>
# <meta content="https://movies.yahoo.com.tw" property="og:url"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" name="twitter:description"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" name="description"/>
# <meta content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態" property="og:description"/>
# ...

# %%
html = soup.find("select", attrs={'name':'movie_id'})
#html = soup.find_all(attrs={'name':'movie_id'}) #the same result 
html.find_all('option',attrs={'data-name':re.compile('.*')}) #去除第一行  #  .*表示所有
# Out:
# [<option data-name="東京喰種S" value="10562">東京喰種S</option>,
#  <option data-name="我的學生都是配樂大師" value="10557">我的學生都是配樂大師</option>,
#  <option data-name="我們的家不是我們的家" value="10556">我們的家不是我們的家</option>,
#  <option data-name="奧斯卡配樂大師：亞歷山大戴斯培" value="10552">奧斯卡配樂大師：亞歷山大戴斯培</option>,
#  <option data-name="聲入奇境：經典配樂大師" value="10550">聲入奇境：經典配樂大師</option>,
#  <option data-name="絕命直播" value="10548">絕命直播</option>,
#  <option data-name="託陰2：布拉姆回來了" value="10540">託陰2：布拉姆回來了</option>,
#  <option data-name="迷雁返家路" value="10533">迷雁返家路</option>,
#  <option data-name="無聲救援" value="10521">無聲救援</option>,
#  <option data-name="鏡中驚魂" value="10514">鏡中驚魂</option>,
#  <option data-name="最初的晚餐" value="10510">最初的晚餐</option>,
#  <option data-name="抓住救命稻草的野獸們" value="10507">抓住救命稻草的野獸們</option>,
#  <option data-name="第六感生死戀" value="10504">第六感生死戀</option>,
#  <option data-name="Re從零開始的異世界生活 外傳集" value="10480">Re從零開始的異世界生活 外傳集</option>,
#  <option data-name="記憶屋" value="10470">記憶屋</option>,
# ...

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 東京喰種S, ID: 10562
# Movie: 我的學生都是配樂大師, ID: 10557
# Movie: 我們的家不是我們的家, ID: 10556
# Movie: 奧斯卡配樂大師：亞歷山大戴斯培, ID: 10552
# Movie: 聲入奇境：經典配樂大師, ID: 10550
# Movie: 絕命直播, ID: 10548
# Movie: 託陰2：布拉姆回來了, ID: 10540
# Movie: 迷雁返家路, ID: 10533
# Movie: 無聲救援, ID: 10521
# Movie: 鏡中驚魂, ID: 10514
# Movie: 最初的晚餐, ID: 10510
# Movie: 抓住救命稻草的野獸們, ID: 10507
# Movie: 第六感生死戀, ID: 10504
# Movie: Re從零開始的異世界生活 外傳集, ID: 10480
# Movie: 記憶屋, ID: 10470
# Movie: 不愛鋼琴師, ID: 10542
# Movie: 神之一手：鬼手篇, ID: 10520
# Movie: 囚愛之家, ID: 10515
# Movie: A+瞎妹, ID: 10508
# Movie: 搖滾師匠：細野晴臣, ID: 10502
# Movie: 最後晚安曲, ID: 10499
# Movie: 我出去醫下, ID: 10494
# Movie: 依然相信, ID: 10487
# Movie: 電影版 地獄少女, ID: 10525
# Movie: 刺激1995, ID: 10518
# Movie: 通靈少年2020, ID: 10517
# Movie: 安雅的回家路, ID: 10516
# Movie: 牆內的房客, ID: 10512
# Movie: 南山的部長們, ID: 10509
# Movie: 另類神父, ID: 10500
# Movie: 破．局, ID: 10496
# Movie: 劇場版 不起眼女主角培育法 Fine, ID: 10486
# Movie: 練愛iNG, ID: 10442
# Movie: 鋼鐵勳章, ID: 10432
# Movie: 我，最親愛的, ID: 10503
# Movie: 血衛, ID: 10469
# ...

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10557

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 三月 31
# 四月 1
# 四月 2
# 四月 3
# 四月 4

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-04-01"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})

# %%
html
# Out:
# [<ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
#  <span>02-87805566</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1585670400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '我的學生都是配樂大師']" data-movie="29bde07e558940f9af96b74a7200c66a" data-movie_date="04.01" data-movie_time="17:50" data-movie_title="我的學生都是配樂大師" data-movie_type="數位" data-session="bbd4012f12a7456c922d523de799363f" data-time="1585734600" id="73417366" name="schedule_list" type="radio" value="2020-04-01 17:50:00"/>
#  <label class="select" for="73417366">17:50</label>
# ...

# %%
'''
print('電影院:' ,html[0]['data-theater_name'] )
print('放映類型:' ,html[0].find(class_='tapR').text)
print( html[1].find(class_='gabtn')['value'] )
print( html[1] )
'''
print(html[1].find() )
for i in html:
    print('電影院:' ,i['data-theater_name'] )
    print('放映類型:' ,i.find(class_='tapR').text)
    print( i.find(class_='gabtn')['value'] )
# Out:
# None
# 電影院: 台北信義威秀影城
# 放映類型: 數位
# 2020-04-01 17:50:00
# 電影院: 喜樂時代影城南港店
# 放映類型: 數位
# 2020-04-01 11:10:00

# %%
'''
  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
'''
# Out:
# ----------------------------------------------------------------------
# 電影院:  台北美麗華大直影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 11:10:00
# 2019-08-21 13:15:00
# 2019-08-21 15:20:00
# 2019-08-21 19:30:00
# 2019-08-21 21:40:00
# 2019-08-21 22:30:00
# ----------------------------------------------------------------------
# 電影院:  台北新光影城
# 放映類型:  數位
# 2019-08-21 10:00:00
# 2019-08-21 14:50:00
# 2019-08-21 19:30:00
# ----------------------------------------------------------------------
# 電影院:  台北in89豪華數位影城
# 放映類型:  數位
# 2019-08-21 09:30:00
# 2019-08-21 11:20:00
# 2019-08-21 13:15:00
# 2019-08-21 15:10:00
# 2019-08-21 16:10:00
# 2019-08-21 17:10:00
# 2019-08-21 18:05:00
# 2019-08-21 19:10:00
# 2019-08-21 21:10:00
# 2019-08-21 23:10:00
# 2019-08-22 01:10:00
# ----------------------------------------------------------------------
# 電影院:  台北日新威秀影城
# 放映類型:  數位
# 2019-08-21 09:00:00
# 2019-08-21 10:55:00
# 2019-08-21 12:50:00
# 2019-08-21 14:45:00
# 2019-08-21 16:40:00
# ...
