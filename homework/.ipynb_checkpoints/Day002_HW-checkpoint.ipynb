# %%
file = 'D:/GitHub/2nd-PyCrawlerMarathon/Data/example.csv'
with open(file,'r',encoding = 'utf-8') as f:
    txt = f.read()
print(txt[:1000],'\n',type(txt))
# Out:
# ﻿序號,路線編號,起訖站,平/假日,站名,班次1,班次2,班次3,班次4,班次5,班次6,班次7,班次8,班次9,班次10,班次11,是否單邊停靠
# 1,51,香山區公所—火車站（先經中山路）,平日,香山區公所,06:30,07:50,09:10,10:30,12:00,13:20,14:40,16:10,18:10,19:40,21:10,否
# 2,51,香山區公所—火車站（先經中山路）,平日,香山國小,06:32,07:52,09:12,10:32,12:02,13:22,14:42,16:12,18:12,19:42,21:12,否
# 3,51,香山區公所—火車站（先經中山路）,平日,聖德宮,06:33,07:53,09:13,10:33,12:03,13:23,14:43,16:13,18:13,19:43,21:13,否
# 4,51,香山區公所—火車站（先經中山路）,平日,頂埔社區,06:34,07:55,09:15,10:35,12:05,13:24,14:45,16:15,18:15,19:45,21:15,否
# 5,51,香山區公所—火車站（先經中山路）,平日,大鵬新城,06:36,07:57,09:17,10:37,12:07,13:26,14:47,16:17,18:17,19:47,21:17,單邊停靠
# 6,51,香山區公所—火車站（先經中山路）,平日,台貿四村,06:38,07:59,09:19,10:39,12:09,13:28,14:49,16:19,18:19,19:49,21:19,單邊停靠
# 7,51,香山區公所—火車站（先經中山路）,平日,天公壇,06:39,08:01,09:21,10:41,12:11,13:29,14:51,16:21,18:21,19:51,21:21,單邊停靠
# 8,51,香山區公所—火車站（先經中山路）,平日,中山路,06:41,08:03,09:23,10:43,12:13,13:31,14:53,16:23,18:23,19:53,21:23,單邊停靠
# 9,51,香山區公所—火車站（先經中山路）,平日,西門口,06:42,08:04,09:24,10:44,12:14,13:32,14:54,16:24,18:24,19:54,21:24,單邊停靠
# ...

# %%
import csv
file = 'D:/GitHub/2nd-PyCrawlerMarathon/Data/example.csv'
with open(file,newline='',encoding='utf-8') as csvfile:
    table = [row for row in csv.reader(csvfile)]
print(table[:10],'\n',type(table))
# Out:
# [['\ufeff序號', '路線編號', '起訖站', '平/假日', '站名', '班次1', '班次2', '班次3', '班次4', '班次5', '班次6', '班次7', '班次8', '班次9', '班次10', '班次11', '是否單邊停靠'], ['1', '51', '香山區公所—火車站（先經中山路）', '平日', '香山區公所', '06:30', '07:50', '09:10', '10:30', '12:00', '13:20', '14:40', '16:10', '18:10', '19:40', '21:10', '否'], ['2', '51', '香山區公所—火車站（先經中山路）', '平日', '香山國小', '06:32', '07:52', '09:12', '10:32', '12:02', '13:22', '14:42', '16:12', '18:12', '19:42', '21:12', '否'], ['3', '51', '香山區公所—火車站（先經中山路）', '平日', '聖德宮', '06:33', '07:53', '09:13', '10:33', '12:03', '13:23', '14:43', '16:13', '18:13', '19:43', '21:13', '否'], ['4', '51', '香山區公所—火車站（先經中山路）', '平日', '頂埔社區', '06:34', '07:55', '09:15', '10:35', '12:05', '13:24', '14:45', '16:15', '18:15', '19:45', '21:15', '否'], ['5', '51', '香山區公所—火車站（先經中山路）', '平日', '大鵬新城', '06:36', '07:57', '09:17', '10:37', '12:07', '13:26', '14:47', '16:17', '18:17', '19:47', '21:17', '單邊停靠'], ['6', '51', '香山區公所—火車站（先經中山路）', '平日', '台貿四村', '06:38', '07:59', '09:19', '10:39', '12:09', '13:28', '14:49'
# ...

# %%
#1,2
column = table[0]
shift1 = []
for i in range(len(column)):
    if column[i] == '班次{}'.format(1):
        row1 = i
        break
for line in range(1,len(table)):
    shift1.append(table[line][row1])
print(shift1)
# Out:
# ['06:30', '06:32', '06:33', '06:34', '06:36', '06:38', '06:39', '06:41', '06:42', '06:43', '06:44', '06:45', '06:46', '06:47', '06:48', '06:49', '06:50', '06:51', '06:53', '06:55', '06:57', '06:58', '07:00', '07:01', '07:03', '07:05', '07:07', '07:09', '07:10', '07:12', '07:14', '07:16', '07:18', '07:20', '07:21', '07:23', '07:24', '07:25', '07:00', '07:02', '07:03', '07:04', '07:06', '07:08', '07:09', '07:11', '07:12', '07:13', '07:14', '07:15', '07:16', '07:17', '07:18', '07:19', '07:20', '07:21', '07:23', '07:25', '07:27', '07:28', '07:30', '07:31', '07:33', '07:35', '07:37', '07:39', '07:40', '07:42', '07:44', '07:46', '07:48', '07:49', '07:51', '07:53', '07:54', '07:55']

# %%
#3
column = table[0]
for i in range(1,6):
    globals()['shift%s'%i] = []
    for j in range(len(column)):
        if column[j] == '班次{}'.format(i):
            globals()['row%s'%i] = j
            break
    for line in range(1,len(table)):
        globals()['shift%s'%i].append(table[line][j])
print(shift1,'\n',shift5)
# Out:
# ['06:30', '06:32', '06:33', '06:34', '06:36', '06:38', '06:39', '06:41', '06:42', '06:43', '06:44', '06:45', '06:46', '06:47', '06:48', '06:49', '06:50', '06:51', '06:53', '06:55', '06:57', '06:58', '07:00', '07:01', '07:03', '07:05', '07:07', '07:09', '07:10', '07:12', '07:14', '07:16', '07:18', '07:20', '07:21', '07:23', '07:24', '07:25', '07:00', '07:02', '07:03', '07:04', '07:06', '07:08', '07:09', '07:11', '07:12', '07:13', '07:14', '07:15', '07:16', '07:17', '07:18', '07:19', '07:20', '07:21', '07:23', '07:25', '07:27', '07:28', '07:30', '07:31', '07:33', '07:35', '07:37', '07:39', '07:40', '07:42', '07:44', '07:46', '07:48', '07:49', '07:51', '07:53', '07:54', '07:55']
# ...
